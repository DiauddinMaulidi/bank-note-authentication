# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from sklearn.neighbors import KNeighborsClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/siswa_lulus_gagal.csv')
#df.head()
df.tail(10)
# Out:
#      Mandiri_Harian  Kursus_Bulanan  Gagal_Atau_Berhasil
# 990               4              39                    0
# 991               2              40                    0
# 992               9              32                    1
# 993               5              38                    0
# 994               7              26                    1
# 995               6              22                    1
# 996               9              30                    1
# 997               3              39                    0
# 998               7              25                    1
# 999               5              37                    0

# %%
x = df.drop('Gagal_Atau_Berhasil',axis = 1)
y = df.Gagal_Atau_Berhasil

# %%
x
# Out:
#      Mandiri_Harian  Kursus_Bulanan
# 0                 7              27
# 1                 2              43
# 2                 7              26
# 3                 8              29
# 4                 3              42
# ..              ...             ...
# 995               6              22
# 996               9              30
# 997               3              39
# 998               7              25
# 999               5              37
#
# [1000 rows x 2 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 995    1
# 996    1
# 997    0
# 998    1
# 999    0
# Name: Gagal_Atau_Berhasil, Length: 1000, dtype: int64

# %% [markdown]
# ### PLOT DATA

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grid = sns.FacetGrid(df, hue='Gagal_Atau_Berhasil', height=5)
grid.map(plt.scatter, 'Mandiri_Harian','Kursus_Bulanan').add_legend()

# %% [markdown]
# ### Model

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=4)

# %%
model = KNeighborsClassifier(n_neighbors=7)  
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
print('\nThe number of neighbors used to predict the target : ',model.n_neighbors)
# Out:
# The number of neighbors used to predict the target :  7

# %%
# predict the target on the train dataset
predict_train = model.predict(x_train)
#print('\nTarget on train data',predict_train) 

# Accuray Score on train dataset
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print('accuracy_score on train dataset : ', accuracy_train)
# Out:
# accuracy_score on train dataset :  0.9866666666666667

# %%
# predict the target on the test dataset
predict_test = model.predict(x_test)
#print('\nTarget on test data',predict_test) 

# Accuray Score on test dataset
accuracy_test = metrics.accuracy_score(y_test,predict_test)
print('accuracy_score on test dataset : ', accuracy_test)
# Out:
# accuracy_score on test dataset :  0.988

# %%
cm = metrics.confusion_matrix(y_test, predict_test)
print(cm)
# Out:
# [[125   3]
#  [  0 122]]

# %% [markdown]
# ### PREDIKSI DATA BARU

# %%
# predicting whether a student will fail or pass
First_Friend = model.predict((np.array([4, 38]).reshape(1, -1)))
print(First_Friend) 

# predicting whether a student will fail or pass
Second_Friend = model.predict((np.array([8, 28]).reshape(1, -1)))
print(Second_Friend)
# Out:
# [0]
# [1]
